# %%
import pandas as pd
import numpy as np

# %%
# Dry_Bean_Dataset.csv
# test.csv

# %%
data1 = pd.read_excel('Dry_Bean_Dataset.xlsx') 
data2 = pd.read_csv('test.csv')

# %%
# data1.to_csv("ActualDry_Bean.csv")

# %%
data3=pd.read_csv('ActualDry_Bean.csv')

# %%
data3 =data3.rename({"Unnamed: 0":"ID"} ,axis=1)

# %%
data3
# Out:
#           ID   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0          0  28395    610.291       208.178117       173.888747
# 1          1  28734    638.018       200.524796       182.734419
# 2          2  29380    624.110       212.826130       175.931143
# 3          3  30008    645.884       210.557999       182.516516
# 4          4  30140    620.134       201.847882       190.279279
# ...      ...    ...        ...              ...              ...
# 13606  13606  42097    759.696       288.721612       185.944705
# 13607  13607  42101    757.499       281.576392       190.713136
# 13608  13608  42139    759.321       281.539928       191.187979
# 13609  13609  42147    763.779       283.382636       190.275731
# 13610  13610  42159    772.237       295.142741       182.204716
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 0          1.197191      0.549812       28715     190.141097  0.763923
# ...

# %%
data3.to_csv("ActualDry.csv")

# %%
data3.loc[data3["ID"]==10835.000000]
# Out:
#           ID   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 10835  10835  28033    636.761        246.19205       145.481788
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 10835      1.692253      0.806724       28429     188.925181  0.747746
#
#        Solidity  roundness  Compactness  ShapeFactor1  ShapeFactor2  \
# 10835  0.986071   0.868813     0.767389      0.008782      0.001879
#
#        ShapeFactor3  ShapeFactor4     Class
# 10835      0.588887      0.996545  DERMASON

# %%
data2.loc[1,"ID":]
# Out:
# ID                 10835.000000
# Area               28772.000000
# Perimeter            630.362000
# MajorAxisLength      229.990785
# MinorAxisLength      159.609367
# AspectRation           1.440960
# Eccentricity           0.719993
# ConvexArea         29127.000000
# EquivDiameter        191.399185
# Extent                 0.767458
# Solidity               0.987812
# roundness              0.909913
# Compactness            0.832204
# ShapeFactor1           0.007994
# ShapeFactor2           0.002365
# ShapeFactor3           0.692563
# ShapeFactor4           0.997956
# Name: 1, dtype: float64

# %%
13611 - 2709
# Out:
# 10902

# %%
data3.shape
# Out:
# (13611, 18)

# %%
data2.shape
# Out:
# (2709, 17)

# %%
data5= pd.read_csv("ActualDry.csv")
data6= pd.read_csv('test.csv')

# %%
data5
# Out:
#           ID   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0          0  28395    610.291       208.178117       173.888747
# 1          1  28734    638.018       200.524796       182.734419
# 2          2  29380    624.110       212.826130       175.931143
# 3          3  30008    645.884       210.557999       182.516516
# 4          4  30140    620.134       201.847882       190.279279
# ...      ...    ...        ...              ...              ...
# 13606  13606  42097    759.696       288.721612       185.944705
# 13607  13607  42101    757.499       281.576392       190.713136
# 13608  13608  42139    759.321       281.539928       191.187979
# 13609  13609  42147    763.779       283.382636       190.275731
# 13610  13610  42159    772.237       295.142741       182.204716
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 0          1.197191      0.549812       28715     190.141097  0.763923
# ...

# %%
data6
# Out:
#          ID    Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0     10834   57659    955.434       387.757607       196.625782
# 1     10835   28772    630.362       229.990785       159.609367
# 2     10836   54677    911.022       308.853903       226.398571
# 3     10837   24827    578.304       214.192699       147.788172
# 4     10838  141850   1432.847       524.923471       346.910920
# ...     ...     ...        ...              ...              ...
# 2704  13538   66833   1018.336       400.397077       214.346215
# 2705  13539   40572    725.331       250.714014       206.471935
# 2706  13540   61226   1008.378       408.227467       199.385082
# 2707  13541   34238    698.847       255.829224       170.867099
# 2708  13542   49175    828.597       310.354804       202.329323
#
#       AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 0         1.972059      0.861896       60188     270.949661  0.620790
# ...

# %%
import csv
t2 = open("ActualDry.csv", 'r')
t1 = open('test.csv', 'r')
fileone = t1.readlines()
filetwo = t2.readlines()
t1.close()
t2.close()

outFile = open('update.csv', 'w')
x = 0
for i in fileone:
    if i != filetwo[x]:
        outFile.write(filetwo[x])
    x += 1
outFile.close()

# %%
data8080=pd.read_csv("update.csv")

# %%
data8080
# Out:
#            ID   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0         0.0  28395    610.291       208.178117       173.888747
# 1         1.0  28734    638.018       200.524796       182.734419
# 2         2.0  29380    624.110       212.826130       175.931143
# 3         3.0  30008    645.884       210.557999       182.516516
# 4         4.0  30140    620.134       201.847882       190.279279
# ...       ...    ...        ...              ...              ...
# 2716  13538.0  66833   1018.336       400.397077       214.346215
# 2717  13539.0  40572    725.331       250.714014       206.471935
# 2718  13540.0  61226   1008.378       408.227467       199.385082
# 2719  13541.0  34238    698.847       255.829224       170.867099
# 2720  13542.0  49175    828.597       310.354804       202.329323
#
#       AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 0         1.197191      0.549812       28715     190.141097  0.763923
# ...

# %%
# data5= pd.read_csv("ActualDry.csv")
# data6= pd.read_csv('test.csv')

# %%
import csv
t2 = open("update.csv", 'r')
t1 = open('test.csv', 'r')
fileone = t1.readlines()
filetwo = t2.readlines()
t1.close()
t2.close()

outFile = open('update22.csv', 'w')
x = 0
for i in fileone:
    if i != filetwo[x]:
        outFile.write(filetwo[x])
    x += 1
outFile.close()

# %%
import pandas as pd

# %%
d =  pd.read_csv("update22.csv")

# %%
d
# Out:
#         ID   Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0        0  28395    610.291       208.178117       173.888747      1.197191
# 1        1  28734    638.018       200.524796       182.734419      1.097356
# 2        2  29380    624.110       212.826130       175.931143      1.209713
# 3        3  30008    645.884       210.557999       182.516516      1.153638
# 4        4  30140    620.134       201.847882       190.279279      1.060798
# ...    ...    ...        ...              ...              ...           ...
# 2704  2704  69886   1084.538       386.131604       231.551316      1.667585
# 2705  2705  69892   1052.973       389.855771       228.671466      1.704873
# 2706  2706  69900   1039.311       387.104369       230.419673      1.679997
# 2707  2707  69923   1053.345       368.807948       242.685901      1.519693
# 2708  2708  69949   1119.198       367.497012       243.000360      1.512331
#
# ...
